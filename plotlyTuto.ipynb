# %%
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
from scipy import special

py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x = np.linspace(0, np.pi, 100)
layout = go.Layout(
    title = 'sample example',
    yaxis=dict(
        title='volts'
    ),
    xaxis = dict(
        title = 'nanoseconds'
    )
)

# %%
trace1 = go.Scatter(
    x = x,
    y = np.sin(x),
    mode = 'lines', # or markers or lines+markes
    name = 'sin x',
    line = dict(shape = 'spline')
)

fig = go.Figure(data = [trace1], layout = layout)
py.offline.iplot(fig)
# Out:
# <div>
#
#
#             <div id="e5f35c45-ee4d-4386-8c93-e5051fff7139" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e5f35c45-ee4d-4386-8c93-e5051fff7139")) {
#                     Plotly.newPlot(
#                         'e5f35c45-ee4d-4386-8c93-e5051fff7139',
# ...

# %%
def update_plot(signals, freq):
    
    data = []
    for s in signals:
        trace1 = go.Scatter(
            x = x,
            y = special.jv(s, freq*x),
            mode = 'lines', # or markers or lines+markes
            name = 'bessel {}'.format(s),
            line = dict(shape = 'spline')
        )
        data.append(trace1)

    fig = go.Figure(data = data, layout = layout)
    py.offline.iplot(fig)
    
signals = widgets.SelectMultiple(options = list(range(6)), value = (0,), description = 'bessel oorder')
freq = widgets.FloatSlider(min = 1, max = 20, value = 1, description = 'Freq')
widgets.interactive(update_plot, signals = signals, freq = freq)
# Out:
# interactive(children=(SelectMultiple(description='bessel oorder', index=(0,), options=(0, 1, 2, 3, 4, 5), valu…

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")

fig = go.Figure()
fig.add_trace(go.Scatter(x=df.Date, y=df['AAPL.High'], name="AAPL High",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=df.Date, y=df['AAPL.Low'], name="AAPL Low",
                         line_color='dimgray'))

fig.update_layout(title_text='Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="b8a3e692-28da-45d9-8e9a-dcd2dd470c5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b8a3e692-28da-45d9-8e9a-dcd2dd470c5d")) {
#                     Plotly.newPlot(
#                         'b8a3e692-28da-45d9-8e9a-dcd2dd470c5d',
# ...

# %%
df.head()
# Out:
#          Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0  2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1  2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2  2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3  2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4  2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
#
#    AAPL.Adjusted          dn        mavg          up   direction
# 0     122.905254  106.741052  117.927667  129.114281  Increasing
# 1     123.760965  107.842423  118.940333  130.038244  Increasing
# 2     123.501363  108.894245  119.889167  130.884089  Decreasing
# 3     124.510914  109.785449  120.763500  131.741551  Increasing
# 4     127.876074  110.372516  121.720167  133.067817  Increasing
